# %% [markdown]
# # 04 – Baseline Models: TF-IDF + ML Klasik
#
# Notebook ini membangun dan membandingkan beberapa model baseline
# untuk analisis sentimen komentar YouTube terkait isu dugaan korupsi
# proyek Kereta Cepat Whoosh.
#
# Dataset input:
# - `data/clean_comments.csv` (hasil preprocessing)
#
# Model yang digunakan:
# 1. Logistic Regression + TF-IDF
# 2. Linear SVM + TF-IDF
# 3. Multinomial Naive Bayes + TF-IDF
#
# Output:
# - Metrik evaluasi (accuracy, precision, recall, f1-score)
# - Confusion matrix per model
# - Ringkasan perbandingan performa
# - Simpan model & vectorizer ke folder `models/`
